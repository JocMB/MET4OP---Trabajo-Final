# %%
import pandas as pd, matplotlib.pyplot as plt, geopandas as gpd, contextily as ctx, numpy as np

# %%
censo_vivienda = pd.read_csv(
    r'C:\Users\leand_5odr3v\Desktop\rocio python\Data met4op\simulacion\censo\vivienda.csv', 
    delimiter=',',
    header=0,
    names=None,
    index_col=0,
    usecols=None,
    dtype=None,
    skiprows=None,
    skipfooter=0,
    nrows=None,
    decimal='.',
    quotechar='"',
)
censo_vivienda.head()
# Out:
#                  RADIO_REF_ID  TIPVV  V01  V02  V00  URP  INCALSERV  INMAT  \
# VIVIENDA_REF_ID
# 1                           1      1    1    1    0    1          1      1
# 2                           1      1    7    1    0    1          1      2
# 3                           1      1    4    1    0    1          1      1
# 4                           1      1    4    1    0    1          1      1
# 5                           1      1    1    1    0    1          3      3
#
#                      MUNI    LOCAL  INCALCONS  TOTHOG
# VIVIENDA_REF_ID
# 1                20010001  2001010          1       2
# 2                20010001  2001010          2       2
# 3                20010001  2001010          1       2
# 4                20010001  2001010          1       1
# 5                20010001  2001010          2       1

# %%
circuitos = gpd.read_file(
    r'C:\Users\leand_5odr3v\Desktop\rocio python\Data met4op\simulacion\elecciones\CABA.shp',)

circuitos
# Out:
#     distrito                        provincia departamen   cabecera circuito  \
# 0         01  Ciudad Autónoma de Buenos Aires   Comuna 1   Comuna 1     0003
# 1         01  Ciudad Autónoma de Buenos Aires   Comuna 4   Comuna 4     0045
# 2         01  Ciudad Autónoma de Buenos Aires   Comuna 3   Comuna 3     0037
# 3         01  Ciudad Autónoma de Buenos Aires   Comuna 1   Comuna 1     0018
# 4         01  Ciudad Autónoma de Buenos Aires  Comuna 13  Comuna 13     0141
# ..       ...                              ...        ...        ...      ...
# 162       01  Ciudad Autónoma de Buenos Aires  Comuna 13  Comuna 13     0135
# 163       01  Ciudad Autónoma de Buenos Aires  Comuna 14  Comuna 14     0149
# 164       01  Ciudad Autónoma de Buenos Aires   Comuna 9   Comuna 9     0101
# 165       01  Ciudad Autónoma de Buenos Aires  Comuna 10  Comuna 10     0102
# 166       01  Ciudad Autónoma de Buenos Aires   Comuna 8   Comuna 8     0088
#
# ...

# %%
circuitos = circuitos[['circuito', 'indec_p', 'indec_d', 'geometry']]
circuitos
# Out:
#     circuito indec_p indec_d  \
# 0       0003      02     001
# 1       0045      02     004
# 2       0037      02     003
# 3       0018      02     001
# 4       0141      02     013
# ..       ...     ...     ...
# 162     0135      02     013
# 163     0149      02     014
# 164     0101      02     009
# 165     0102      02     010
# 166     0088      02     008
#
#                                               geometry
# 0    POLYGON Z ((-6496304.252 -4084732.697 0.000, -...
# 1    POLYGON Z ((-6501230.474 -4091702.182 0.000, -...
# 2    POLYGON Z ((-6501166.688 -4087904.826 0.000, -...
# 3    POLYGON Z ((-6498832.986 -4088373.028 0.000, -...
# 4    POLYGON Z ((-6503862.400 -4078547.361 0.000, -...
# ..                                                 ...
# 162  POLYGON Z ((-6507834.614 -4077215.626 0.000, -...
# 163  POLYGON Z ((-6503253.371 -4080723.227 0.000, -...
# 164  POLYGON Z ((-6515182.479 -4090061.116 0.000, -...
# ...

# %%
circuitos['IDDPTO'] = circuitos.indec_p.str.cat(circuitos.indec_d, sep=' ')
circuitos
# Out:
# c:\Users\leand_5odr3v\anaconda3\envs\MET4OP\lib\site-packages\geopandas\geodataframe.py:1472: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#     circuito indec_p indec_d  \
# 0       0003      02     001
# 1       0045      02     004
# 2       0037      02     003
# 3       0018      02     001
# 4       0141      02     013
# ..       ...     ...     ...
# 162     0135      02     013
# 163     0149      02     014
# 164     0101      02     009
# 165     0102      02     010
# 166     0088      02     008
#
#                                               geometry  IDDPTO
# 0    POLYGON Z ((-6496304.252 -4084732.697 0.000, -...  02 001
# 1    POLYGON Z ((-6501230.474 -4091702.182 0.000, -...  02 004
# ...

# %%
radios = gpd.read_file(
    r'C:\Users\leand_5odr3v\Desktop\rocio python\Data met4op\simulacion\censo\radios censales\CABA_radios.shp')
radios.head()
# Out:
#        RADIO  VULNERABIL       NSE CENTRO_DE_            HOSPITAL POSTA_SANI  \
# 0  020010101    0.802284 -0.456724     16.348              38.006     105.48
# 1  020010201    0.817588 -0.456724     16.976               46.61    133.978
# 2  020010202    0.820031 -0.456724     18.384              48.838    135.066
# 3  020010203    0.818413 -0.456724     14.448              48.746    131.126
# 4  020010204    0.825755 -0.456724     11.074  50.410000000000004    121.272
#
#   IDPROV                              PROV IDDPTO      DPTO    REDCODE  \
# 0     02  Ciudad AutÃ³noma de Buenos Aires  02001  Comuna 1  020010101
# 1     02  Ciudad AutÃ³noma de Buenos Aires  02001  Comuna 1  020010201
# 2     02  Ciudad AutÃ³noma de Buenos Aires  02001  Comuna 1  020010202
# 3     02  Ciudad AutÃ³noma de Buenos Aires  02001  Comuna 1  020010203
# 4     02  Ciudad AutÃ³noma de Buenos Aires  02001  Comuna 1  020010204
#
#    RADIOS_POB  RADIOS_HOG  RADIOS_LAT  RADIOS_LON  RADIOS_SUP  \
# ...

# %%
radios = radios[['RADIO', 'IDPROV', 'IDDPTO', 'RADIOS_LAT', 'RADIOS_LON', 'geometry']]
radios
# Out:
#           RADIO IDPROV IDDPTO  RADIOS_LAT  RADIOS_LON  \
# 0     020010101     02  02001  -34.586689  -58.368836
# 1     020010201     02  02001  -34.578623  -58.386987
# 2     020010202     02  02001  -34.579194  -58.387533
# 3     020010203     02  02001  -34.580158  -58.385503
# 4     020010204     02  02001  -34.580006  -58.382654
# ...         ...    ...    ...         ...         ...
# 3548  020152109     02  02015  -34.599727  -58.431162
# 3549  020152110     02  02015  -34.598933  -58.430166
# 3550  020152111     02  02015  -34.598226  -58.429006
# 3551  020152112     02  02015  -34.597576  -58.427811
# 3552  020152113     02  02015  -34.597213  -58.425920
#
#                                                geometry
# 0     POLYGON ((-58.37430 -34.57870, -58.36801 -34.5...
# 1     POLYGON ((-58.38920 -34.57818, -58.38893 -34.5...
# 2     POLYGON ((-58.38909 -34.57855, -58.38890 -34.5...
# 3     POLYGON ((-58.38603 -34.57947, -58.38508 -34.5...
# ...
